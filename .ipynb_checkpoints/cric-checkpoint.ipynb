# %%
# !uv pip install -q langchain langchain_openai langchain-google-genai python-dotenv

# %%
import requests
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from groq import Groq
from dotenv import load_dotenv
import os
from bs4 import BeautifulSoup
import time
from datetime import datetime, timedelta
from kokoro import KPipeline
import soundfile as sf
import numpy as np
import pandas as pd
import warnings
import random

# %% [markdown]
# # LLM **Integration**

# %%
load_dotenv()

OpenRouterapi_key = os.getenv("OR_API_KEY")
Gemini_api_key = os.getenv('GEMINI_API_KEY')
OPENRouter_API_BASE= os.getenv('OPENRouter_API_BASE')
GROQ_API_KEY = os.getenv('GROQ_API_KEY')

# %%
openai_model = ChatOpenAI(
    model="openai/gpt-oss-120b:free",  # Or the desired OpenRouter model
    openai_api_base=OPENRouter_API_BASE,
    openai_api_key=OpenRouterapi_key,
)

nvidia_model = ChatOpenAI(
    model="nvidia/nemotron-3-super-120b-a12b:free",  # Or the desired OpenRouter model
    openai_api_base=OPENRouter_API_BASE,
    openai_api_key=OpenRouterapi_key
)

free_model = ChatOpenAI(
    model="openrouter/free",  # Or the desired OpenRouter model
    openai_api_base=OPENRouter_API_BASE,
    openai_api_key=OpenRouterapi_key
)

groq_openai_model = ChatGroq(
    model="openai/gpt-oss-120b",
    api_key=GROQ_API_KEY
)

groq_qwen_model = ChatGroq(
    model="qwen/qwen3-32b",
    api_key=GROQ_API_KEY
)

groq_llama_model = ChatGroq(
    model='llama-3.3-70b-versatile',
    api_key = GROQ_API_KEY
)

groq_llama2_model = ChatGroq(
    model='meta-llama/llama-4-scout-17b-16e-instruct',
    api_key = GROQ_API_KEY
)

# %%
system_prompt = '''
You are a live cricket commentary generation agent.

Your task is to transform raw cricket match text into exciting, natural, commentator-style spoken commentary optimized for text-to-speech in English.

The input may include:
- Batter and bowler names
- Runs scored
- Current score
- Wickets
- Type of delivery (yorker, bouncer, fuller ball, short ball, slower ball, etc.)
- Type of shot played (cover drive, pull shot, sweep, lofted shot, cut shot, etc.)
- Match situation
- Over details, extras, boundaries, milestones, and other standard cricket events

Your output must:
- Sound like real live TV or radio cricket commentary
- Be energetic and expressive, especially for wickets, fours, sixes, and big match moments
- Use natural pauses and spoken-style phrasing
- Build excitement where needed without sounding fake or exaggerated
- Keep player names and match details accurate
- Be clear and easy for text-to-speech models to speak naturally
- Complete the full commentary naturally without cutting off important context or ending mid-thought

Style rules:
- Write like a professional live cricket commentator on air
- Add excitement for boundaries, wickets, close chances, and turning points
- Use short, natural spoken sentences
- Use punctuation like commas, ellipses, and exclamation marks to improve delivery
- Avoid robotic, formal, or overly technical language
- Do not invent facts not present in the input
- Do not explain the play, only commentate it naturally

Examples:

Input:
Bumrah to Smith, short ball, he goes for the pull, gets the top edge and fine leg takes the catch. Australia 145 for 5.

Output:
Bumrah with the short ball… Smith goes for the pull… gets the top edge, and he's taken! Fine leg completes the catch. A big breakthrough for India, and Australia slip to 145 for 5!

Input:
Shami to Rohit Sharma, full outside off, beautifully driven through covers for four. India 78 for 1.

Output:
Shami bowls it full outside off, and Rohit drives it beautifully through the covers! That's a glorious boundary, four runs. India move to 78 for 1.

Return only the transformed live commentary and nothing else.
'''

# %%
all_models = [groq_openai_model, groq_qwen_model, groq_llama_model, groq_llama2_model]

llm_model = random.choice(all_models)

# %%
comms_agent = create_agent(
    model = llm_model,
    system_prompt = system_prompt,
    # verbose = True,
)

# %%
def call_llm(humanmessage):
    global comms_agent
    response = comms_agent.invoke({
        'messages': [HumanMessage(content=humanmessage)]
    })
    return response['messages'][-1].content

# %% [markdown]
# # Commentary Scraping

# %%
url= "https://www.cricbuzz.com/live-cricket-scores/151935/dc-vs-rcb-39th-match-indian-premier-league-2026"

# %%
div_data = pd.DataFrame(columns=['Id', 'Raw_comms', 'Modified_comms', 'AudioFile_Flag'])

# %%
def table_update(Id, Raw_comms, Modified_comms, AudioFile_Flag):
    global div_data
    new_row = pd.DataFrame([{'Id':Id, 'Raw_comms': Raw_comms, 'Modified_comms': Modified_comms, 'AudioFile_Flag': int(AudioFile_Flag)}])
    div_data=pd.concat([div_data, new_row])

# %%
def refresh_data():
    print("Data Load Started. Time: ", datetime.now())
    global div_data
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    div_elements = soup.find('div', class_="mb-2 wb:m-0 leading-6 wb:py-3")
    layer1_div = div_elements.find_all('div', recursive = False)
    for n,i in enumerate(layer1_div):
        data=i.get_text(strip=False, separator=' -- ')
        if len(data)> 10 and data not in div_data['Raw_comms'].values:
            table_update(datetime.now().strftime('%H:%M:%S.%f'),data,call_llm(data),0)
    div_data=div_data.sort_values(by='Id', ascending = False)
    print("Data Load Completed. Time: ", datetime.now())

# %%
def audio_flag_update():
    global div_data
    global audio_div_data
    audio_div_data = div_data[div_data['AudioFile_Flag'] == 0].copy()
    audio_div_data = audio_div_data.sort_values(by='Id', ascending = False)
    for i in audio_div_data['Modified_comms'].values:
        audio_id=audio_div_data.loc[audio_div_data['Modified_comms'] == i, 'Id'].iloc[0]
        # print('Converted Text: \n\n', i)
        generate_audio(i,str(audio_id))
        div_data.loc[div_data['Id'] ==audio_id, 'AudioFile_Flag'] = 1
        audio_div_data.loc[audio_div_data['Id'] == audio_id, 'AudioFile_Flag'] = 1
        print("Audio Flag Updated")

# %% [markdown]
# # Text-To-Speech

# %%
warnings.filterwarnings("ignore")
pipeline = KPipeline(
    lang_code='a',
    repo_id='hexgrad/Kokoro-82M'
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
def generate_audio(commentary, audio_id):
    generator = pipeline(
        commentary,
        voice="am_santa",
        speed=1.0
    )

    all_audio = []

    for i, (gs, ps, audio) in enumerate(generator):
        all_audio.append(audio)
    print(f"Generated chunk {i+1}")

    final_audio = np.concatenate(all_audio)

    output_path = f"Audio Files/{audio_id}_commentary.wav"
    sf.write(output_path, final_audio, 24000)

    print(f"{output_path} file generated")

# %% [markdown]
# # Main functions

# %%
match_start = datetime.now()
match_ends = match_start + timedelta(minutes=1)
print('Match start time: ',match_start)
print('Match end time: ', match_ends)
loop = 1
while datetime.now() < match_ends:
    print(f"Loop Number: {loop} start time",datetime.now())
    refresh_data()
    audio_flag_update()
    print(f"Loop Number: {loop} end time",datetime.now())
    loop+=1
    time.sleep(60)

print("Match Completed")
# Out:
# Match start time:  2026-04-27 12:51:21.706445
# Match end time:  2026-04-27 12:52:21.706445
# Loop Number: 1 start time 2026-04-27 12:51:21.706584
# Data Load Started. Time:  2026-04-27 12:51:21.706594
# Data Load Completed. Time:  2026-04-27 12:51:24.957444
# Converted Text:
#
#  Welcome to the Royal Challengers Bengaluru squad lineup... we've got a strong team shaping up here! Jacob Bethell, the young talent, alongside the experienced Virat Kohli... Devdutt Padikkal, a name to watch out for... and leading the side is Rajat Patidar, with Jitesh Sharma behind the stumps.
#
# Tim David brings the power, Krunal Pandya, the seasoned all-rounder... Romario Shepherd adds some flair... Bhuvneshwar Kumar and Josh Hazlewood, the pace duo... Suyash Sharma, Rasikh Salam Dar, a couple of youngsters with potential.
#
# And let's not forget Jordan Cox, Mangesh Yadav, Vicky Ostwal, Venkatesh Iyer... Philip Salt, the wicketkeeper-batter... Jacob Duffy, Nuwan Thushara, the overseas recruits... Abhinandan Singh, Swapnil Singh, Vihaan Malhotra, Kanishk Chouhan, and Satvik Deswal, all part of the squad.
#
# It's a mix of youth and experience... a team looking to make a strong impact this season! The Royal Challengers Bengaluru are ready to take on the competition!
# Generated chunk 4
# Audio Files/12:51:24.231686_commentary.wav file generated
# Audio Flag Updated
# Converted Text:
#
#  And welcome back to the Delhi Capitals squad announcement! We've got a strong-looking team here, folks...
#
# Pathum Nissanka, KL Rahul leading the side as wicketkeeper... Nitish Rana, David Miller, and Sameer Rizvi in the middle order... Axar Patel, the captain, alongside Tristan Stubbs...
#
# The bowling department looks exciting too... Kuldeep Yadav, T Natarajan, Mukesh Kumar... and some big names in the pace department, Lungi Ngidi, Ashutosh Sharma, Dushmantha Chameera...
#
# The overseas players make a big impact... Mitchell Starc, Kyle Jamieson... and Rehan Ahmed, a young talent...
#
# The batting lineup has some big hitters... Karun Nair, Prithvi Shaw... and some youngsters getting a chance, Abishek Porel, Sahil Parakh, Madhav Tiwari...
#
# This Delhi Capitals team has a great balance... let's see how they perform this season!
# Generated chunk 6
# Audio Files/12:51:23.582470_commentary.wav file generated
# Audio Flag Updated
# Converted Text:
#
#  And welcome back to the Arun Jaitley Stadium in Delhi, where the Capitals are looking to bounce back from a crushing defeat to the Punjab Kings! They were chasing a world-record 265, and it didn't go their way. But they've got a quick turnaround, and now they're hosting the Royal Challengers Bengaluru, who are sitting pretty in second place!
#
# Delhi's had a bit of a slump, four losses in their last five games, and they'll need to get back on track quickly, especially with RCB coming to town. The Capitals' pace department is a bit depleted, with Lungi Ngidi's injury and Mitchell Starc not available until next month.
#
# RCB, on the other hand, are looking strong, with Virat Kohli still in the Orange Cap conversation. Their collective batting has been impressive, with Devdutt Padikkal and Rajat Patidar adding stability and firepower. And with Bhuvneshwar Kumar leading their attack, they've got a good chance to exploit Delhi's batting frailties.
#
# It's going to be a run-fest, folks! The average first innings total in Delhi since IPL 2023 is 200. RCB hold a clear advantage in head-to-head encounters, but since 2023, the rivalry has been evenly poised.
#
# The teams are out, and we're just about to get underway! Pathum Nissanka and KL Rahul are walking out for Delhi, while Virat Kohli and Devdutt Padikkal are leading the charge for RCB. Bhuvneshwar Kumar is starting proceedings for RCB... and here's the first ball!
# Generated chunk 5
# Audio Files/12:51:22.377547_commentary.wav file generated
# Audio Flag Updated
# Converted Text:
#
#  Delhi versus Bengaluru, the stage is set... what a contest we have in store for you today! The Delhi team, looking to make a strong statement... and Bengaluru, with their eyes on a crucial win. The crowd is electric here... let's get underway!
# Generated chunk 1
# Audio Files/12:51:21.885251_commentary.wav file generated
# Audio Flag Updated
# Loop Number: 1 end time 2026-04-27 12:52:18.431055
# Loop Number: 2 start time 2026-04-27 12:52:21.436256
# Data Load Started. Time:  2026-04-27 12:52:21.436768
# Data Load Completed. Time:  2026-04-27 12:52:21.715462
# Loop Number: 2 end time 2026-04-27 12:52:21.717416
# Match Completed
